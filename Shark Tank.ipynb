# %% [markdown]
# # Shark Tank EDA
# ![28shark-tank-india-3.jpg](attachment:28shark-tank-india-3.jpg)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
shark_data=pd.read_csv("C:/Users/em/Downloads/Shark Tank India Dataset.csv")

# %%
shark_data # check the data
# Out:
#      episode_number  pitch_number           brand_name  \
# 0                 1             1  BluePine Industries
# 1                 1             2        Booz scooters
# 2                 1             3  Heart up my Sleeves
# 3                 2             4           Tagz Foods
# 4                 2             5       Head and Heart
# ..              ...           ...                  ...
# 112              34           113        Green Protein
# 113              34           114              On2Cook
# 114              35           115        Jain Shikanji
# 115              35           116                Woloo
# 116              35           117         Elcare India
#
#                                               idea  deal  pitcher_ask_amount  \
# 0                                     Frozen Momos     1                50.0
# 1    Renting e-bike for mobility in private spaces     1                40.0
# ...

# %%
shark_data.head(5) # to check top 5 record
# Out:
#    episode_number  pitch_number           brand_name  \
# 0               1             1  BluePine Industries
# 1               1             2        Booz scooters
# 2               1             3  Heart up my Sleeves
# 3               2             4           Tagz Foods
# 4               2             5       Head and Heart
#
#                                             idea  deal  pitcher_ask_amount  \
# 0                                   Frozen Momos     1                50.0
# 1  Renting e-bike for mobility in private spaces     1                40.0
# 2                             Detachable Sleeves     1                25.0
# 3                           Healthy Potato Chips     1                70.0
# 4                       Brain Development Course     0                50.0
#
#    ask_equity  ask_valuation  deal_amount  deal_equity  ...  ashneer_deal  \
# 0         5.0        1000.00         75.0        16.00  ...             1
# ...

# %%
shark_data.tail(5) # to check bottom 5 record
# Out:
#      episode_number  pitch_number     brand_name                    idea  \
# 112              34           113  Green Protein     Plant-Based Protein
# 113              34           114        On2Cook  Fastest Cooking Device
# 114              35           115  Jain Shikanji                Lemonade
# 115              35           116          Woloo         Washroom Finder
# 116              35           117   Elcare India    Carenting for Elders
#
#      deal  pitcher_ask_amount  ask_equity  ask_valuation  deal_amount  \
# 112     0                60.0         2.0         3000.0          0.0
# 113     0               100.0         1.0        10000.0          0.0
# 114     1                40.0         8.0          500.0         40.0
# 115     0                50.0         4.0         1250.0          0.0
# 116     0               100.0         2.5         4000.0          0.0
#
#      deal_equity  ...  ashneer_deal  anupam_deal  aman_deal  namita_deal  \
# ...

# %%
shark_data.shape # to check the number of rows and column in data
# Out:
# (117, 28)

# %%
# basic information of data
shark_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117 entries, 0 to 116
# Data columns (total 28 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   episode_number         117 non-null    int64
#  1   pitch_number           117 non-null    int64
#  2   brand_name             117 non-null    object
#  3   idea                   117 non-null    object
#  4   deal                   117 non-null    int64
#  5   pitcher_ask_amount     117 non-null    float64
#  6   ask_equity             117 non-null    float64
#  7   ask_valuation          117 non-null    float64
#  8   deal_amount            117 non-null    float64
#  9   deal_equity            117 non-null    float64
#  10  deal_valuation         117 non-null    float64
#  11  ashneer_present        117 non-null    int64
#  12  anupam_present         117 non-null    int64
#  13  aman_present           117 non-null    int64
# ...

# %%
shark_data.isnull().sum() # to check the null value present in our dataset
# Out:
# episode_number           0
# pitch_number             0
# brand_name               0
# idea                     0
# deal                     0
# pitcher_ask_amount       0
# ask_equity               0
# ask_valuation            0
# deal_amount              0
# deal_equity              0
# deal_valuation           0
# ashneer_present          0
# anupam_present           0
# aman_present             0
# namita_present           0
# vineeta_present          0
# peyush_present           0
# ghazal_present           0
# ashneer_deal             0
# anupam_deal              0
# aman_deal                0
# namita_deal              0
# vineeta_deal             0
# peyush_deal              0
# ghazal_deal              0
# total_sharks_invested    0
# amount_per_shark         0
# equity_per_shark         0
# dtype: int64

# %%
shark_data.describe()
# Out:
#        episode_number  pitch_number        deal  pitcher_ask_amount  \
# count      117.000000    117.000000  117.000000          117.000000
# mean        18.735043     59.000000    0.555556          319.854709
# std         10.070778     33.919021    0.499041         2767.842777
# min          1.000000      1.000000    0.000000            0.001010
# 25%         10.000000     30.000000    0.000000           45.000000
# 50%         19.000000     59.000000    1.000000           50.000000
# 75%         27.000000     88.000000    1.000000           80.000000
# max         35.000000    117.000000    1.000000        30000.000000
#
#        ask_equity  ask_valuation  deal_amount  deal_equity  deal_valuation  \
# count  117.000000     117.000000   117.000000   117.000000      117.000000
# mean     5.188034    3852.462479    31.982915     8.963504      467.104872
# std      3.892121   11931.601957    36.687391    13.106769      919.988864
# ...

# %%
shark_data.columns # to check all the columns present in our dataset
# Out:
# Index(['episode_number', 'pitch_number', 'brand_name', 'idea', 'deal',
#        'pitcher_ask_amount', 'ask_equity', 'ask_valuation', 'deal_amount',
#        'deal_equity', 'deal_valuation', 'ashneer_present', 'anupam_present',
#        'aman_present', 'namita_present', 'vineeta_present', 'peyush_present',
#        'ghazal_present', 'ashneer_deal', 'anupam_deal', 'aman_deal',
#        'namita_deal', 'vineeta_deal', 'peyush_deal', 'ghazal_deal',
#        'total_sharks_invested', 'amount_per_shark', 'equity_per_shark'],
#       dtype='object')

# %%
shark_data.select_dtypes(include=['object'])
# Out:
#               brand_name                                           idea
# 0    BluePine Industries                                   Frozen Momos
# 1          Booz scooters  Renting e-bike for mobility in private spaces
# 2    Heart up my Sleeves                             Detachable Sleeves
# 3             Tagz Foods                           Healthy Potato Chips
# 4         Head and Heart                       Brain Development Course
# ..                   ...                                            ...
# 112        Green Protein                            Plant-Based Protein
# 113              On2Cook                         Fastest Cooking Device
# 114        Jain Shikanji                                       Lemonade
# 115                Woloo                                Washroom Finder
# 116         Elcare India                           Carenting for Elders
#
# [117 rows x 2 columns]

# %% [markdown]
# There are 2 columns which is in categorial value

# %%
shark_data.select_dtypes(include=['int','float'])
# Out:
#      episode_number  pitch_number  deal  pitcher_ask_amount  ask_equity  \
# 0                 1             1     1                50.0         5.0
# 1                 1             2     1                40.0        15.0
# 2                 1             3     1                25.0        10.0
# 3                 2             4     1                70.0         1.0
# 4                 2             5     0                50.0         5.0
# ..              ...           ...   ...                 ...         ...
# 112              34           113     0                60.0         2.0
# 113              34           114     0               100.0         1.0
# 114              35           115     1                40.0         8.0
# 115              35           116     0                50.0         4.0
# 116              35           117     0               100.0         2.5
#
#      ask_valuation  deal_amount  deal_equity  deal_valuation  ashneer_present  \
# ...

# %%
# check the data of first 10 columns
shark_data.iloc[0:5,0:10]
# Out:
#    episode_number  pitch_number           brand_name  \
# 0               1             1  BluePine Industries
# 1               1             2        Booz scooters
# 2               1             3  Heart up my Sleeves
# 3               2             4           Tagz Foods
# 4               2             5       Head and Heart
#
#                                             idea  deal  pitcher_ask_amount  \
# 0                                   Frozen Momos     1                50.0
# 1  Renting e-bike for mobility in private spaces     1                40.0
# 2                             Detachable Sleeves     1                25.0
# 3                           Healthy Potato Chips     1                70.0
# 4                       Brain Development Course     0                50.0
#
#    ask_equity  ask_valuation  deal_amount  deal_equity
# 0         5.0        1000.00         75.0        16.00
# 1        15.0         266.67         40.0        50.00
# ...

# %%
# check data 10 to 20 columns
shark_data.iloc[0:5,10:21]
# Out:
#    deal_valuation  ashneer_present  anupam_present  aman_present  \
# 0          468.75                1               1             1
# 1           80.00                1               1             1
# 2           83.33                1               1             1
# 3         2545.45                1               1             1
# 4            0.00                1               1             1
#
#    namita_present  vineeta_present  peyush_present  ghazal_present  \
# 0               1                1               0               0
# 1               1                1               0               0
# 2               1                1               0               0
# 3               1                1               0               0
# 4               1                1               0               0
#
#    ashneer_deal  anupam_deal  aman_deal
# 0             1            0          1
# 1             1            0          0
# 2             0            1          0
# ...

# %% [markdown]
# # 2: Cleaning the data

# %% [markdown]
# # Checking missing values if yes then handle them accordingly

# %% [markdown]
# - we see that from above analysis there is no missing and null values

# %%
# to check duplicate record
shark_data.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 112    False
# 113    False
# 114    False
# 115    False
# 116    False
# Length: 117, dtype: bool

# %% [markdown]
# - we can see that there is no duplicate record present so no need to drop the columns

# %% [markdown]
# # INSIGHTS

# %%
shark_data.head(2)
# Out:
#    episode_number  pitch_number           brand_name  \
# 0               1             1  BluePine Industries
# 1               1             2        Booz scooters
#
#                                             idea  deal  pitcher_ask_amount  \
# 0                                   Frozen Momos     1                50.0
# 1  Renting e-bike for mobility in private spaces     1                40.0
#
#    ask_equity  ask_valuation  deal_amount  deal_equity  ...  ashneer_deal  \
# 0         5.0        1000.00         75.0         16.0  ...             1
# 1        15.0         266.67         40.0         50.0  ...             1
#
#    anupam_deal  aman_deal  namita_deal  vineeta_deal  peyush_deal  \
# 0            0          1            0             1            0
# 1            0          0            0             1            0
#
#    ghazal_deal  total_sharks_invested  amount_per_shark  equity_per_shark
# 0            0                      3              25.0          5.333333
# ...

# %% [markdown]
# # How many Duplicated rows present

# %%
shark_data[shark_data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [episode_number, pitch_number, brand_name, idea, deal, pitcher_ask_amount, ask_equity, ask_valuation, deal_amount, deal_equity, deal_valuation, ashneer_present, anupam_present, aman_present, namita_present, vineeta_present, peyush_present, ghazal_present, ashneer_deal, anupam_deal, aman_deal, namita_deal, vineeta_deal, peyush_deal, ghazal_deal, total_sharks_invested, amount_per_shark, equity_per_shark]
# Index: []
#
# [0 rows x 28 columns]

# %% [markdown]
# - There is no duplicate rows present in our dataset

# %% [markdown]
# # Find the number of episodes

# %%
shark_data['episode_number'].nunique()
# Out:
# 35

# %% [markdown]
# - Total number of 35 episode in shark tank

# %%
# to check the count of number of deal done or not
shark_data['deal'].value_counts()
# Out:
# 1    65
# 0    52
# Name: deal, dtype: int64

# %% [markdown]
#  - Total number of deal done is 1 is 65
#  - Total number of deal not done is 0 is 52

# %%
# to check the maximum deal amount done on the episode
shark_data[shark_data['deal_amount']==shark_data['deal_amount'].max()]
# Out:
#     episode_number  pitch_number     brand_name        idea  deal  \
# 50              17            51  Aas Vidyalaya  EdTech App     1
#
#     pitcher_ask_amount  ask_equity  ask_valuation  deal_amount  deal_equity  \
# 50               150.0         3.0         5000.0        150.0         15.0
#
#     ...  ashneer_deal  anupam_deal  aman_deal  namita_deal  vineeta_deal  \
# 50  ...             1            0          0            1             0
#
#     peyush_deal  ghazal_deal  total_sharks_invested  amount_per_shark  \
# 50            1            0                      3              50.0
#
#     equity_per_shark
# 50               5.0
#
# [1 rows x 28 columns]

# %%
# to check the maximum ask valuation in the episode
shark_data[shark_data['ask_valuation']==shark_data['ask_valuation'].max()]
# Out:
#     episode_number  pitch_number  brand_name             idea  deal  \
# 30              11            31  Gopal's 56  Fiber Ice Cream     0
#
#     pitcher_ask_amount  ask_equity  ask_valuation  deal_amount  deal_equity  \
# 30             30000.0        25.0       120000.0          0.0          0.0
#
#     ...  ashneer_deal  anupam_deal  aman_deal  namita_deal  vineeta_deal  \
# 30  ...             0            0          0            0             0
#
#     peyush_deal  ghazal_deal  total_sharks_invested  amount_per_shark  \
# 30            0            0                      0               0.0
#
#     equity_per_shark
# 30               0.0
#
# [1 rows x 28 columns]

# %% [markdown]
# - Maximum ask valuation is 120000

# %%
# to check the minimum equity ask in the episode
shark_data[shark_data['ask_equity']==shark_data['ask_equity'].min()]
# Out:
#    episode_number  pitch_number   brand_name                     idea  deal  \
# 6               3             7  Qzense Labs  Food Freshness Detector     0
#
#    pitcher_ask_amount  ask_equity  ask_valuation  deal_amount  deal_equity  \
# 6               100.0        0.25        40000.0          0.0          0.0
#
#    ...  ashneer_deal  anupam_deal  aman_deal  namita_deal  vineeta_deal  \
# 6  ...             0            0          0            0             0
#
#    peyush_deal  ghazal_deal  total_sharks_invested  amount_per_shark  \
# 6            0            0                      0               0.0
#
#    equity_per_shark
# 6               0.0
#
# [1 rows x 28 columns]

# %% [markdown]
# - Minimum asked equity is 0.25

# %%
# to check maximum ask valuation 
shark_data[shark_data['ask_valuation']==shark_data['ask_valuation'].max()]
# Out:
#     episode_number  pitch_number  brand_name             idea  deal  \
# 30              11            31  Gopal's 56  Fiber Ice Cream     0
#
#     pitcher_ask_amount  ask_equity  ask_valuation  deal_amount  deal_equity  \
# 30             30000.0        25.0       120000.0          0.0          0.0
#
#     ...  ashneer_deal  anupam_deal  aman_deal  namita_deal  vineeta_deal  \
# 30  ...             0            0          0            0             0
#
#     peyush_deal  ghazal_deal  total_sharks_invested  amount_per_shark  \
# 30            0            0                      0               0.0
#
#     equity_per_shark
# 30               0.0
#
# [1 rows x 28 columns]

# %% [markdown]
# # Max, min , mean of asked amount,asked equity, asked valuation ?

# %%
shark_data[['pitcher_ask_amount','ask_equity','ask_valuation']].agg([max,min,'mean'])
# Out:
#       pitcher_ask_amount  ask_equity  ask_valuation
# max         30000.000000   25.000000  120000.000000
# min             0.001010    0.250000       0.010000
# mean          319.854709    5.188034    3852.462479

# %% [markdown]
# # Max & Min asked- equity,asked-valuation and asked amount episode-wise ?

# %%
shark_data.head(2)
# Out:
#    episode_number  pitch_number           brand_name  \
# 0               1             1  BluePine Industries
# 1               1             2        Booz scooters
#
#                                             idea  deal  pitcher_ask_amount  \
# 0                                   Frozen Momos     1                50.0
# 1  Renting e-bike for mobility in private spaces     1                40.0
#
#    ask_equity  ask_valuation  deal_amount  deal_equity  ...  ashneer_deal  \
# 0         5.0        1000.00         75.0         16.0  ...             1
# 1        15.0         266.67         40.0         50.0  ...             1
#
#    anupam_deal  aman_deal  namita_deal  vineeta_deal  peyush_deal  \
# 0            0          1            0             1            0
# 1            0          0            0             1            0
#
#    ghazal_deal  total_sharks_invested  amount_per_shark  equity_per_shark
# 0            0                      3              25.0          5.333333
# ...

# %%
shark_data.groupby(['episode_number'])[('pitcher_ask_amount','ask_equity','ask_valuation')].agg([max,min])
# Out:
# C:\Users\em\AppData\Local\Temp\ipykernel_4552\3623356012.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   shark_data.groupby(['episode_number'])[('pitcher_ask_amount','ask_equity','ask_valuation')].agg([max,min])
#                pitcher_ask_amount           ask_equity       ask_valuation  \
#                               max       min        max   min           max
# episode_number
# 1                            50.0  25.00000       15.0  5.00       1000.00
# 2                            70.0  50.00000        5.0  1.00       7000.00
# 3                           100.0  50.00000        4.0  0.25      40000.00
# 4                            75.0  50.00000       10.0  4.00       1875.00
# 5                           100.0  10.00000       20.0  1.00      10000.00
# 6                           100.0  45.00000       10.0  1.00      10000.00
# ...

# %% [markdown]
# # Brand names in which 2 ,3 or 4 sharks are invested ?

# %%
# dataframe shows that those brand get invested 2 to 4
shark_data[(shark_data['total_sharks_invested']>=2) & (shark_data['total_sharks_invested']<=4)][['brand_name','total_sharks_invested']]
# Out:
#                          brand_name  total_sharks_invested
# 0               BluePine Industries                      3
# 1                     Booz scooters                      2
# 2               Heart up my Sleeves                      2
# 9                             Cosiq                      2
# 11                           Bummer                      2
# 12                      Revamp Moto                      2
# 18               Raising Superstars                      2
# 21                     Beyond Snack                      2
# 22   Vivalyf Innovations- Easy Life                      2
# 24                            Altor                      2
# 25                            Ariro                      2
# 27                          Nuutjob                      3
# 28                         Meatyour                      3
# 29                        EventBeep                      3
# 32                            Farda                      2
# ...

# %% [markdown]
# # Episode wise minimum and maximum of sharks invested ?

# %%
shark_data.head(2)
# Out:
#    episode_number  pitch_number           brand_name  \
# 0               1             1  BluePine Industries
# 1               1             2        Booz scooters
#
#                                             idea  deal  pitcher_ask_amount  \
# 0                                   Frozen Momos     1                50.0
# 1  Renting e-bike for mobility in private spaces     1                40.0
#
#    ask_equity  ask_valuation  deal_amount  deal_equity  ...  ashneer_deal  \
# 0         5.0        1000.00         75.0         16.0  ...             1
# 1        15.0         266.67         40.0         50.0  ...             1
#
#    anupam_deal  aman_deal  namita_deal  vineeta_deal  peyush_deal  \
# 0            0          1            0             1            0
# 1            0          0            0             1            0
#
#    ghazal_deal  total_sharks_invested  amount_per_shark  equity_per_shark
# 0            0                      3              25.0          5.333333
# ...

# %%
#maximum and minimum invested by sharks in every episode
shark_data.groupby(['episode_number'])['total_sharks_invested'].agg([max,min])
# Out:
#                 max  min
# episode_number
# 1                 3    2
# 2                 1    0
# 3                 1    0
# 4                 2    0
# 5                 2    0
# 6                 5    0
# 7                 2    0
# 8                 2    1
# 9                 2    0
# 10                3    3
# 11                2    0
# 12                3    0
# 13                4    2
# 14                2    0
# 15                3    1
# 16                2    0
# 17                5    0
# 18                1    0
# 19                4    0
# 20                5    0
# 21                3    1
# 22                3    0
# 23                1    0
# 24                2    0
# 25                5    0
# 26                1    0
# 27                4    0
# 28                3    0
# 29                3    0
# 30                2    0
# 31                1    0
# 32                1    0
# 33                3    0
# 34                4    0
# 35                4    0

# %% [markdown]
# # Obervation

# %% [markdown]
# - We can see that in episode 6,17,20,25 all the sharks invested
# - minimum is in so many episodes 0

# %% [markdown]
# # Minimum and Maximum sharks invested in each brand ?

# %%
 shark_data.groupby(['brand_name'])['total_sharks_invested'].agg([max,min])
# Out:
#                                 max  min
# brand_name
# ARRCOAT Surface Textures          1    1
# Aas Vidyalaya                     3    3
# Agro tourism                      0    0
# Aliste Technologies               0    0
# Alpino                            0    0
# ...                             ...  ...
# Vivalyf Innovations- Easy Life    2    2
# Wakao Foods                       3    3
# Watt Technovations                4    4
# WeSTOCK                           4    4
# Woloo                             0    0
#
# [117 rows x 2 columns]

# %% [markdown]
# # Brand names who ask for 1 crore and got a deal ?

# %%
shark_data.head(2)
# Out:
#    episode_number  pitch_number           brand_name  \
# 0               1             1  BluePine Industries
# 1               1             2        Booz scooters
#
#                                             idea  deal  pitcher_ask_amount  \
# 0                                   Frozen Momos     1                50.0
# 1  Renting e-bike for mobility in private spaces     1                40.0
#
#    ask_equity  ask_valuation  deal_amount  deal_equity  ...  ashneer_deal  \
# 0         5.0        1000.00         75.0         16.0  ...             1
# 1        15.0         266.67         40.0         50.0  ...             1
#
#    anupam_deal  aman_deal  namita_deal  vineeta_deal  peyush_deal  \
# 0            0          1            0             1            0
# 1            0          0            0             1            0
#
#    ghazal_deal  total_sharks_invested  amount_per_shark  equity_per_shark
# 0            0                      3              25.0          5.333333
# ...

# %%
shark_data[(shark_data['pitcher_ask_amount']==100)&(shark_data['deal_amount']==100)][['brand_name','pitcher_ask_amount','deal_amount']]
# Out:
#              brand_name  pitcher_ask_amount  deal_amount
# 12          Revamp Moto               100.0        100.0
# 18   Raising Superstars               100.0        100.0
# 39    The Renal Project               100.0        100.0
# 64           Get a Whey               100.0        100.0
# 79  Sunfox Technologies               100.0        100.0
# 87   Insurance Samadhan               100.0        100.0

# %% [markdown]
# # Brand names who asked equity between 0 to 50 ?

# %%
shark_data.head(2)
# Out:
#    episode_number  pitch_number           brand_name  \
# 0               1             1  BluePine Industries
# 1               1             2        Booz scooters
#
#                                             idea  deal  pitcher_ask_amount  \
# 0                                   Frozen Momos     1                50.0
# 1  Renting e-bike for mobility in private spaces     1                40.0
#
#    ask_equity  ask_valuation  deal_amount  deal_equity  ...  ashneer_deal  \
# 0         5.0        1000.00         75.0         16.0  ...             1
# 1        15.0         266.67         40.0         50.0  ...             1
#
#    anupam_deal  aman_deal  namita_deal  vineeta_deal  peyush_deal  \
# 0            0          1            0             1            0
# 1            0          0            0             1            0
#
#    ghazal_deal  total_sharks_invested  amount_per_shark  equity_per_shark
# 0            0                      3              25.0          5.333333
# ...

# %%
shark_data[(shark_data['ask_equity']>=0) & (shark_data['ask_equity'])<=50][['brand_name','ask_equity']]
# Out:
#               brand_name  ask_equity
# 0    BluePine Industries         5.0
# 1          Booz scooters        15.0
# 2    Heart up my Sleeves        10.0
# 3             Tagz Foods         1.0
# 4         Head and Heart         5.0
# ..                   ...         ...
# 112        Green Protein         2.0
# 113              On2Cook         1.0
# 114        Jain Shikanji         8.0
# 115                Woloo         4.0
# 116         Elcare India         2.5
#
# [117 rows x 2 columns]

# %% [markdown]
# # Brand names where deal equity is between 0 to 50 ?

# %%
# showing which brand name in which deal equity is between 0 to 50
shark_data[(shark_data['deal_equity']>=0) & (shark_data['deal_equity']<=50)][['brand_name','deal_equity']]
# Out:
#               brand_name  deal_equity
# 0    BluePine Industries        16.00
# 1          Booz scooters        50.00
# 2    Heart up my Sleeves        30.00
# 3             Tagz Foods         2.75
# 4         Head and Heart         0.00
# ..                   ...          ...
# 112        Green Protein         0.00
# 113              On2Cook         0.00
# 114        Jain Shikanji        30.00
# 115                Woloo         0.00
# 116         Elcare India         0.00
#
# [116 rows x 2 columns]

# %% [markdown]
# # Find the number of brands participated in each episode ?

# %%
shark_data['episode_number'].value_counts()
# Out:
# 18    4
# 30    4
# 17    4
# 16    4
# 22    4
# 23    4
# 27    4
# 31    4
# 32    4
# 33    4
# 34    4
# 19    4
# 29    3
# 28    3
# 20    3
# 26    3
# 25    3
# 24    3
# 21    3
# 1     3
# 2     3
# 15    3
# 14    3
# 13    3
# 12    3
# 11    3
# 10    3
# 9     3
# 8     3
# 7     3
# 6     3
# 5     3
# 4     3
# 3     3
# 35    3
# Name: episode_number, dtype: int64

# %% [markdown]
# # Insights
# - maximum number of brands particapted in per episode is 4
# - minimum number  of brands particapted in per episode is 3

# %% [markdown]
# # How many sharks participated in this show and What were their names ?

# %%
shark_data.head(2)
# Out:
#    episode_number  pitch_number           brand_name  \
# 0               1             1  BluePine Industries
# 1               1             2        Booz scooters
#
#                                             idea  deal  pitcher_ask_amount  \
# 0                                   Frozen Momos     1                50.0
# 1  Renting e-bike for mobility in private spaces     1                40.0
#
#    ask_equity  ask_valuation  deal_amount  deal_equity  ...  ashneer_deal  \
# 0         5.0        1000.00         75.0         16.0  ...             1
# 1        15.0         266.67         40.0         50.0  ...             1
#
#    anupam_deal  aman_deal  namita_deal  vineeta_deal  peyush_deal  \
# 0            0          1            0             1            0
# 1            0          0            0             1            0
#
#    ghazal_deal  total_sharks_invested  amount_per_shark  equity_per_shark
# 0            0                      3              25.0          5.333333
# ...

# %%
# sharks name which is particapted in ths show
shark_data.columns[11:18]
# Out:
# Index(['ashneer_present', 'anupam_present', 'aman_present', 'namita_present',
#        'vineeta_present', 'peyush_present', 'ghazal_present'],
#       dtype='object')

# %%
# count of sharks which are participated in show
len(shark_data.columns[11:18])
# Out:
# 7

# %%
sns.countplot(x='total_sharks_invested',data=shark_data)
# Out:
# <AxesSubplot:xlabel='total_sharks_invested', ylabel='count'>

# %% [markdown]
# # Find appearance of each sharks?

# %%
l = []
for i in shark_data.columns[11:18]:
    l.append(shark_data[i].sum())

# Create a DataFrame for shark appearances
sharks_appearance_data = {'sharks': ['ashneer_deal', 'anupam_deal', 'aman_deal', 'namita_deal', 'vineeta_deal', 'peyush_deal', 'ghazal_deal'],
                          'sharks_appearance_data': l}
sharks_appearance = pd.DataFrame(sharks_appearance_data)

# Plot the bar chart
plt.bar(sharks_appearance['sharks'], sharks_appearance['sharks_appearance_data'])
plt.xticks(rotation=90)
plt.title('Sharks Appearance in Series')
plt.show()

# %% [markdown]
# # Obervations
# - Anupam appeared maximum in episode in shark tank
# - Ghazal appeared minimum in epiode in shark tank

# %% [markdown]
# # How many entrepreneurs were present ?

# %%
shark_data.head(2)
# Out:
#    episode_number  pitch_number           brand_name  \
# 0               1             1  BluePine Industries
# 1               1             2        Booz scooters
#
#                                             idea  deal  pitcher_ask_amount  \
# 0                                   Frozen Momos     1                50.0
# 1  Renting e-bike for mobility in private spaces     1                40.0
#
#    ask_equity  ask_valuation  deal_amount  deal_equity  ...  ashneer_deal  \
# 0         5.0        1000.00         75.0         16.0  ...             1
# 1        15.0         266.67         40.0         50.0  ...             1
#
#    anupam_deal  aman_deal  namita_deal  vineeta_deal  peyush_deal  \
# 0            0          1            0             1            0
# 1            0          0            0             1            0
#
#    ghazal_deal  total_sharks_invested  amount_per_shark  equity_per_shark
# 0            0                      3              25.0          5.333333
# ...

# %%
shark_data['brand_name'].nunique()
# Out:
# 117

# %% [markdown]
# # Obervation
# - Total 117 number of enterpenure is present

# %% [markdown]
# # How many times each investers invested the deal ?

# %%
for i in shark_data.columns[18:25]:
    s=shark_data[i].sum()
    print(i,'deal count',s)
# Out:
# ashneer_deal deal count 21
# anupam_deal deal count 24
# aman_deal deal count 28
# namita_deal deal count 22
# vineeta_deal deal count 15
# peyush_deal deal count 27
# ghazal_deal deal count 7

# %% [markdown]
# # Obervation
# - Maximum number of investor is aman_deal
# - Minimum number of investor is ghazal_deal

# %% [markdown]
# # Calculating the total amount invested by the sharks

# %%
l=[]
for i in shark_data.columns[18:25]:
    x=shark_data[shark_data[i]==1]
    s=x['amount_per_shark'].sum()
    l.append(s)
    print(i,'invested',s,'amount')
    amount=sorted(l,reverse=False)
    amount
# Out:
# ashneer_deal invested 494.33333333 amount
# anupam_deal invested 533.83360253 amount
# aman_deal invested 887.500016693 amount
# namita_deal invested 648.333602533 amount
# vineeta_deal invested 328.3333333300001 amount
# peyush_deal invested 719.6669191630001 amount
# ghazal_deal invested 130.0002525 amount

# %% [markdown]
# # Obervations
# - Aman invested maximum amount i.e 887.50001 amount
# - Lowest amount invested by ghazal i.e 130 amount

# %% [markdown]
# # Find the equity percent that each sharks gets ?

# %%
shark_data.head(2)
# Out:
#    episode_number  pitch_number           brand_name  \
# 0               1             1  BluePine Industries
# 1               1             2        Booz scooters
#
#                                             idea  deal  pitcher_ask_amount  \
# 0                                   Frozen Momos     1                50.0
# 1  Renting e-bike for mobility in private spaces     1                40.0
#
#    ask_equity  ask_valuation  deal_amount  deal_equity  ...  ashneer_deal  \
# 0         5.0        1000.00         75.0         16.0  ...             1
# 1        15.0         266.67         40.0         50.0  ...             1
#
#    anupam_deal  aman_deal  namita_deal  vineeta_deal  peyush_deal  \
# 0            0          1            0             1            0
# 1            0          0            0             1            0
#
#    ghazal_deal  total_sharks_invested  amount_per_shark  equity_per_shark
# 0            0                      3              25.0          5.333333
# ...

# %%
l=[]
for i in shark_data.columns[18:25]:
    x=shark_data[shark_data[i]==1]
    s=x['ask_equity'].sum()
    l.append(s)
    print(i,'gets total',s,'equity')
    amount=sorted(l,reverse=True)
    amount
# Out:
# ashneer_deal gets total 93.5 equity
# anupam_deal gets total 127.0 equity
# aman_deal gets total 118.0 equity
# namita_deal gets total 119.0 equity
# vineeta_deal gets total 92.5 equity
# peyush_deal gets total 135.0 equity
# ghazal_deal gets total 44.0 equity

# %% [markdown]
# # Obervation
# - Highest percentage of equity owned by peyush
# - Lowest percentage of equity owned by ghazal

# %% [markdown]
# # Find the total number of amount invested in this show?

# %%
shark_data.head(2)
# Out:
#    episode_number  pitch_number           brand_name  \
# 0               1             1  BluePine Industries
# 1               1             2        Booz scooters
#
#                                             idea  deal  pitcher_ask_amount  \
# 0                                   Frozen Momos     1                50.0
# 1  Renting e-bike for mobility in private spaces     1                40.0
#
#    ask_equity  ask_valuation  deal_amount  deal_equity  ...  ashneer_deal  \
# 0         5.0        1000.00         75.0         16.0  ...             1
# 1        15.0         266.67         40.0         50.0  ...             1
#
#    anupam_deal  aman_deal  namita_deal  vineeta_deal  peyush_deal  \
# 0            0          1            0             1            0
# 1            0          0            0             1            0
#
#    ghazal_deal  total_sharks_invested  amount_per_shark  equity_per_shark
# 0            0                      3              25.0          5.333333
# ...

# %%
shark_data['deal_amount'].sum()
# Out:
# 3742.00106

# %% [markdown]
# - Total 3742.00106 amount invested in the show

# %% [markdown]
# # Find the highest equity a shark gets ?

# %%
shark_data['equity_per_shark'].max()
# Out:
# 75.0

# %% [markdown]
# # Find the most attracted ideas accepted by sharks ?

# %%
shark_data['total_sharks_invested'].unique()
# Out:
# array([3, 2, 1, 0, 5, 4], dtype=int64)

# %%
# calculating total_sharks_invested greater than 3 with brand name and idea
shark_data[shark_data['total_sharks_invested']>3][['brand_name','idea']]
# Out:
#                 brand_name                            idea
# 15             Skippi Pops                        Ice-Pops
# 38         The Yarn Bazaar                Yarn-Trading App
# 49   Find Your Kicks India                  Sneaker Resale
# 58                 WeSTOCK  Livestock health monitoring AI
# 63                IN A CAN                   Can Cocktails
# 79     Sunfox Technologies             Portable ECG Device
# 85      Watt Technovations             Ventilated PPE Kits
# 110     Nomad Food Project                      Bacon Jams
# 114          Jain Shikanji                        Lemonade

# %%
shark_data[shark_data['ask_valuation']==shark_data['ask_valuation'].max()]
# Out:
#     episode_number  pitch_number  brand_name             idea  deal  \
# 30              11            31  Gopal's 56  Fiber Ice Cream     0
#
#     pitcher_ask_amount  ask_equity  ask_valuation  deal_amount  deal_equity  \
# 30             30000.0        25.0       120000.0          0.0          0.0
#
#     ...  ashneer_deal  anupam_deal  aman_deal  namita_deal  vineeta_deal  \
# 30  ...             0            0          0            0             0
#
#     peyush_deal  ghazal_deal  total_sharks_invested  amount_per_shark  \
# 30            0            0                      0               0.0
#
#     equity_per_shark
# 30               0.0
#
# [1 rows x 28 columns]

# %% [markdown]
# # How many companies in front Owner speak ?

# %%
shark_data.head(2)
# Out:
#    episode_number  pitch_number           brand_name  \
# 0               1             1  BluePine Industries
# 1               1             2        Booz scooters
#
#                                             idea  deal  pitcher_ask_amount  \
# 0                                   Frozen Momos     1                50.0
# 1  Renting e-bike for mobility in private spaces     1                40.0
#
#    ask_equity  ask_valuation  deal_amount  deal_equity  ...  ashneer_deal  \
# 0         5.0        1000.00         75.0         16.0  ...             1
# 1        15.0         266.67         40.0         50.0  ...             1
#
#    anupam_deal  aman_deal  namita_deal  vineeta_deal  peyush_deal  \
# 0            0          1            0             1            0
# 1            0          0            0             1            0
#
#    ghazal_deal  total_sharks_invested  amount_per_shark  equity_per_shark
# 0            0                      3              25.0          5.333333
# ...

# %%
list=['ashneer_deal','anupam_deal','aman_deal','namita_deal','vineeta_deal','peyush_deal','ghazal_deal']
for i in list:
    pres=shark_data[i].sum()
    print(i[:-8],"present in front of",pres,'companies')
# Out:
# ashn present in front of 21 companies
# anu present in front of 24 companies
# a present in front of 28 companies
# nam present in front of 22 companies
# vine present in front of 15 companies
# pey present in front of 27 companies
# gha present in front of 7 companies

# %%
got_invest=shark_data[shark_data['deal_amount']>0.0].shape
got_not_invest=shark_data[shark_data['deal_amount']==0.0].shape
print('total number of companies got the investment',got_invest[0])
print('total number of companies not got the investment',got_not_invest[0])
list1=['Got invested','Not Got Invested']
plt.pie([got_invest[0],got_not_invest[0]],labels=list1,autopct="%.1f%%")
plt.title("Numbers of Company which got invested of not")
plt.show()
# Out:
# total number of companies got the investment 65
# total number of companies not got the investment 52

# %%
shark_data.hist(figsize=(22,22),bins=10)
plt.show()

# %%
import plotly.express as px

# %%
total_shark = shark_data[shark_data["total_sharks_invested"] == 5]
figure = px.bar(total_shark, x='brand_name', y='deal_amount', title="Five Shark Deal ", template="seaborn")
figure.show()
# Out:
# <div>                            <div id="000bb68c-69ed-4a52-87bb-f1889cc3a73c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("000bb68c-69ed-4a52-87bb-f1889cc3a73c")) {                    Plotly.newPlot(                        "000bb68c-69ed-4a52-87bb-f1889cc3a73c",                        [{"alignmentgroup":"True","hovertemplate":"brand_name=%{x}<br>deal_amount=%{y}<extra></extra>","legendgroup":"","marker":{"color":"rgb(76,114,176)","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Skippi Pops","Find Your Kicks India","IN A CAN","Sunfox Technologies"],"xaxis":"x","y":[100.0,50.0,100.0,100.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker
# ...

# %% [markdown]
# From above plot, we get to know that there are all total 4 five shark deal brands and also with the pitcher
# deal amount and the deal amount of the brand.

# %% [markdown]
# # Highest Pitch Ask Amount:

# %%
high=shark_data[shark_data['pitcher_ask_amount']>100]
figure=px.bar(high,x='brand_name',y='pitcher_ask_amount',title='Highest pitched asked',template='seaborn')
figure.show()
# Out:
# <div>                            <div id="5f3a3d74-fd0f-4532-abf4-ba0d8cdd836a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5f3a3d74-fd0f-4532-abf4-ba0d8cdd836a")) {                    Plotly.newPlot(                        "5f3a3d74-fd0f-4532-abf4-ba0d8cdd836a",                        [{"alignmentgroup":"True","hovertemplate":"brand_name=%{x}<br>pitcher_ask_amount=%{y}<extra></extra>","legendgroup":"","marker":{"color":"rgb(76,114,176)","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Gopal's 56","Aas Vidyalaya","KetoIndia","Magic lock","Alpino","Shades of Spring","Experential Etc"],"xaxis":"x","y":[30000.0,150.0,125.0,120.0,150.0,300.0,200.0],"yaxis":"y","type":"bar"}],        
# ...

# %% [markdown]
# # Ask Equity and Deal Equity:

# %%
figure=px.bar(high,x='brand_name',y='ask_equity',title='Ask equity and deal equity' ,template='seaborn')
figure.show()
# Out:
# <div>                            <div id="6e5d610a-1709-4bfa-9e07-944f64f1ca18" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6e5d610a-1709-4bfa-9e07-944f64f1ca18")) {                    Plotly.newPlot(                        "6e5d610a-1709-4bfa-9e07-944f64f1ca18",                        [{"alignmentgroup":"True","hovertemplate":"brand_name=%{x}<br>ask_equity=%{y}<extra></extra>","legendgroup":"","marker":{"color":"rgb(76,114,176)","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Gopal's 56","Aas Vidyalaya","KetoIndia","Magic lock","Alpino","Shades of Spring","Experential Etc"],"xaxis":"x","y":[25.0,3.0,1.25,8.0,2.0,1.0,4.0],"yaxis":"y","type":"bar"}],                        {"temp
# ...

# %%
shark_data.head(2)
# Out:
#    episode_number  pitch_number           brand_name  \
# 0               1             1  BluePine Industries
# 1               1             2        Booz scooters
#
#                                             idea  deal  pitcher_ask_amount  \
# 0                                   Frozen Momos     1                50.0
# 1  Renting e-bike for mobility in private spaces     1                40.0
#
#    ask_equity  ask_valuation  deal_amount  deal_equity  ...  ashneer_deal  \
# 0         5.0        1000.00         75.0         16.0  ...             1
# 1        15.0         266.67         40.0         50.0  ...             1
#
#    anupam_deal  aman_deal  namita_deal  vineeta_deal  peyush_deal  \
# 0            0          1            0             1            0
# 1            0          0            0             1            0
#
#    ghazal_deal  total_sharks_invested  amount_per_shark  equity_per_shark
# 0            0                      3              25.0          5.333333
# ...

# %%
#No. of brands the sharks have invested:
num_deal_shark=[shark_data.ashneer_deal.sum(), shark_data.anupam_deal.sum(), shark_data.aman_deal.sum(), shark_data.namita_deal.sum(),shark_data.vineeta_deal.sum(),shark_data.peyush_deal.sum(),shark_data.ghazal_deal.sum()]
all_sharks=["Ashneer", "Anupam", "Aman", "Namita", "Vineeta", "Peyush", "Ghazal"]
figure=px.bar(total_shark, x=all_sharks, y=num_deal_shark,title="Number of deals done",template="seaborn")
figure.show()
# Out:
# <div>                            <div id="66cc01c3-eb99-4ec5-ba91-b59295e416d4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("66cc01c3-eb99-4ec5-ba91-b59295e416d4")) {                    Plotly.newPlot(                        "66cc01c3-eb99-4ec5-ba91-b59295e416d4",                        [{"alignmentgroup":"True","hovertemplate":"x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"","marker":{"color":"rgb(76,114,176)","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Ashneer","Anupam","Aman","Namita","Vineeta","Peyush","Ghazal"],"xaxis":"x","y":[21,24,28,22,15,27,7],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(234,23
# ...

# %% [markdown]
# # insights
# - Aman invested maximum times and Ghazal invested minimum times

# %% [markdown]
# # Above 50% Equity taken by the shark in which brand:

# %%
shark_equity=shark_data[shark_data['equity_per_shark']>50]
figure=px.bar(shark_equity,x='brand_name',y='equity_per_shark',title='Above 50% equity',template='seaborn')
figure.show()
# Out:
# <div>                            <div id="51ad5347-2320-4758-a2f0-9e5c096976ef" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("51ad5347-2320-4758-a2f0-9e5c096976ef")) {                    Plotly.newPlot(                        "51ad5347-2320-4758-a2f0-9e5c096976ef",                        [{"alignmentgroup":"True","hovertemplate":"brand_name=%{x}<br>equity_per_shark=%{y}<extra></extra>","legendgroup":"","marker":{"color":"rgb(76,114,176)","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Sid07 Designs"],"xaxis":"x","y":[75.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(234,234,242)","width":0.5},"pattern":{"fillm
# ...

# %% [markdown]
# # Obervation
# - only 1 brand name got above 50% equity (Side07 Designs)

# %%
import os

# Get the current working directory
current_directory = os.getcwd()

print("Current Working Directory:", current_directory)
# Out:
# Current Working Directory: C:\Users\em
